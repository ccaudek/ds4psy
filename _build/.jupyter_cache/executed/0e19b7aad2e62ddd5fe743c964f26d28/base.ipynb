# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pymc as pm
import pymc.sampling_jax
import scipy.stats as stats
import arviz as az
import warnings

warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=Warning)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# %config InlineBackend.figure_format = 'retina'
RANDOM_SEED = 42
rng = np.random.default_rng(RANDOM_SEED)
az.style.use("arviz-viridish")

# %%
# Dati
y = 14
ntrials = 100

# %%
# Distribuzione a priori
alpha_prior = 4
beta_prior = 6

# %%
model = pm.Model()

with model:
    # Prior
    theta = pm.Beta("theta", alpha=alpha_prior, beta=beta_prior)
    # Likelihood
    obs = pm.Binomial("obs", p=theta, n=ntrials, observed=y)

# %%
pm.model_to_graphviz(model)

# %%
with model:
    idata1 = pm.sample()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [theta]
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:00<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 13 seconds.

# %%
with model:
    idata2 = pm.sampling_jax.sample_numpyro_nuts()
# Out:
# Compiling...
# Compilation time =  0:00:00.384469
# Sampling...
#   0%|          | 0/2000 [00:00<?, ?it/s]
#   0%|          | 0/2000 [00:00<?, ?it/s]
#   0%|          | 0/2000 [00:00<?, ?it/s]
#   0%|          | 0/2000 [00:00<?, ?it/s]
# Sampling time =  0:00:01.679931
# Transforming variables...
# Transformation time =  0:00:00.015319

# %%
az.plot_trace(idata2)
# Out:
# array([[<Axes: title={'center': 'theta'}>,
#         <Axes: title={'center': 'theta'}>]], dtype=object)

# %%
az.summary(idata2)
# Out:
#         mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# theta  0.161  0.035   0.098    0.226      0.001    0.001    1355.0    1701.0
#
#        r_hat
# theta    1.0

# %%
with model:
    idata3 = pm.sampling_jax.sample_blackjax_nuts()
# Out:
# Compiling...
# Compilation time =  0:00:00.363925
# Sampling...
# Sampling time =  0:00:01.806443
# Transforming variables...
# Transformation time =  0:00:00.008063

# %%
az.summary(idata3)
# Out:
#         mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# theta  0.162  0.036   0.096    0.229      0.001    0.001    1373.0    1738.0
#
#        r_hat
# theta    1.0

# %%
# %load_ext watermark
# %watermark -n -u -v -iv -w -p numpyro,blackjax
# Out:
# Last updated: Sun Sep 17 2023
#
# Python implementation: CPython
# Python version       : 3.11.5
# IPython version      : 8.15.0
#
# numpyro : 0.13.0
# blackjax: 0.9.6
#
# matplotlib: 3.7.2
# arviz     : 0.16.0
# pymc      : 5.6.1
# scipy     : 1.10.1
# seaborn   : 0.12.2
# numpy     : 1.25.2
#
# Watermark: 2.4.3
