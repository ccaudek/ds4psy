# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats 
import pymc as pm
import pymc.sampling_jax
import arviz as az
import warnings

warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=Warning)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# %config InlineBackend.figure_format = 'retina'
RANDOM_SEED = 42
rng = np.random.default_rng(RANDOM_SEED)
az.style.use("arviz-viridish")

# %%
alpha = 4
beta = 6
y = 14
n = 100
alpha_prime = alpha + y
beta_prime = beta + n - y
m = 20
x = np.arange(0, 20)

plt.plot(
    x,
    stats.betabinom.pmf(x, m, alpha_prime, beta_prime),
    "C0o",
    ms=5,
    label="betabinom pmf",
)
_ = plt.vlines(
    x,
    0,
    stats.betabinom.pmf(x, m, alpha_prime, beta_prime),
    colors="C1",
    lw=2,
    alpha=0.5,
)

# Set x-ticks to be every 5 units
plt.xticks(np.arange(0, 21, 5))

plt.xlabel("x")
plt.ylabel("Probability")
plt.title("Beta-Binomial PMF")
# Out:
# Text(0.5, 1.0, 'Beta-Binomial PMF')

# %%
1 - stats.betabinom.cdf(4, m, alpha_prime, beta_prime).sum()
# Out:
# 0.23298739435887628

# %%
x = np.arange(0, 21)
px = stats.betabinom.pmf(np.arange(0, 21), m, alpha_prime, beta_prime)

ev = sum(x * px)
print(ev)
# Out:
# 3.272727272727284

# %%
nrep = 100000
theta = stats.beta.rvs(alpha_prime, beta_prime, size=nrep)
print(*theta[0:10])
# Out:
# 0.18884684528081988 0.10795129055071666 0.1254079675917353 0.21248935558077905 0.16148844557873968 0.18556416563395023 0.1744583905244659 0.19780326214312127 0.16646680175724526 0.10191461648939468

# %%
y_tilde = [stats.binom.rvs(n=20, p=th, size=1) for th in theta]
y_tilde = np.concatenate(y_tilde)
print(*y_tilde[0:50])
# Out:
# 5 3 1 1 1 4 3 3 3 2 2 3 3 6 3 2 3 5 6 5 1 1 3 5 3 5 5 2 3 2 6 3 6 1 7 1 4 6 4 3 0 3 3 3 7 5 3 3 2 2

# %%
hist, bins, _ = plt.hist(y_tilde, bins=range(0, 22), density=True, alpha=0.5)
bin_centers = (bins[:-1] + bins[1:]) / 2
px = stats.betabinom.pmf(np.arange(0, 21), m, alpha_prime, beta_prime)
plt.plot(bin_centers, px, "o", color="C0", label="Beta-Binomial");

# %%
az.plot_posterior(y_tilde, hdi_prob=0.8, kind="kde", bw=0.5);

# %%
ntrials = 100
y = 14

alpha_prior = 4
beta_prior = 6

with pm.Model() as model:
    theta = pm.Beta("theta", alpha=alpha_prior, beta=beta_prior)
    obs = pm.Binomial("obs", p=theta, n=ntrials, observed=y)

# %%
with model:
    idata = pm.sampling_jax.sample_numpyro_nuts()
# Out:
# Compiling...
# Compilation time =  0:00:00.540004
# Sampling...
#   0%|          | 0/2000 [00:00<?, ?it/s]
#   0%|          | 0/2000 [00:00<?, ?it/s]
#   0%|          | 0/2000 [00:00<?, ?it/s]
#   0%|          | 0/2000 [00:00<?, ?it/s]
# Sampling time =  0:00:01.426273
# Transforming variables...
# Transformation time =  0:00:00.016556

# %%
az.summary(idata)
# Out:
#         mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# theta  0.165  0.035   0.104    0.233      0.001    0.001    1446.0    2219.0
#
#        r_hat
# theta    1.0

# %%
with model:
    post_pred = pm.sample_posterior_predictive(idata)
# Out:
# Sampling: [obs]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:00<00:00]
#     </div>

# %%
post_pred.posterior_predictive.obs
# Out:
# <xarray.DataArray 'obs' (chain: 4, draw: 1000)>
# array([[23, 11, 16, ..., 17, 17, 14],
#        [26, 20, 16, ..., 16, 13, 10],
#        [21, 12, 22, ..., 11, 17, 21],
#        [11, 13,  9, ...,  6, 15, 13]])
# Coordinates:
#   * chain    (chain) int64 0 1 2 3
#   * draw     (draw) int64 0 1 2 3 4 5 6 7 8 ... 992 993 994 995 996 997 998 999

# %%
az.plot_posterior(post_pred.posterior_predictive.obs, hdi_prob=0.8)
plt.show()

# %%
post = az.extract(idata)
post["theta"].size
# Out:
# 4000

# %%
y_rep = stats.binom.rvs(n=20, p=post["theta"])

# %%
az.plot_posterior(y_rep, hdi_prob=0.8, kind="kde", bw=0.5)
plt.show()

# %%
print(alpha_prior, beta_prior)
# Out:
# 4 6

# %%
with model:
    idata_prior_pred = pm.sample_prior_predictive()
# Out:
# Sampling: [obs, theta]

# %%
idata_prior_pred
# Out:
# Inference data with groups:
# 	> prior
# 	> prior_predictive
# 	> observed_data

# %%
az.plot_posterior(idata_prior_pred.prior_predictive.obs)
plt.show()

# %%
# %load_ext watermark
# %watermark -n -u -v -iv -w
# Out:
# Last updated: Sun Sep 17 2023
#
# Python implementation: CPython
# Python version       : 3.11.5
# IPython version      : 8.15.0
#
# scipy     : 1.10.1
# matplotlib: 3.7.2
# arviz     : 0.16.0
# pandas    : 2.0.3
# numpy     : 1.25.2
# seaborn   : 0.12.2
# pymc      : 5.6.1
#
# Watermark: 2.4.3
